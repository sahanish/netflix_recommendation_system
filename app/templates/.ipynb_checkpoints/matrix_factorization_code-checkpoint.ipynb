# %%
import numpy as np
np.random.seed(1337)
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from keras.models import Model
from keras.layers import Input, Embedding, Dot, Add, Flatten
from keras.regularizers import l2
from keras.optimizers import SGD, Adam
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('edited_ratings_subset_larger.csv')
df = pd.DataFrame(df)

# %%
N = df.userId.max() + 1
M = df.movie_idx.max() + 1
df = shuffle(df)
df
# Out:
#       userId  movieId  rating  movie_idx
# 478       39      296     4.5          2
# 4897      47     3114     3.5        144
# 194       25     1240     4.0         69
# 6397       5      912     3.5        135
# 5492      23      527     5.0          9
# 740        6     4963     3.5         91
# 2051      10      778     4.5        130
# 1074      28      104     3.5        139
# 4286      32      595     3.0         46
# 6094       8      858     4.0         21
# 6016      14     1222     3.0        128
# 1458      12     1197     3.5         52
# 5429      41     4027     4.0        151
# 5393      41     1387     5.0        168
# 677        6     1270     3.0         33
# 1169      31      457     4.0         22
# 3154       7     1193     4.0         65
# 104       42     4995     4.5         81
# 545       39     2571     4.0          4
# 238       25     3578     3.0         35
# 1180      31      597     5.0         61
# 2802      13      919     5.0        156
# 1523      12     4226     4.5         41
# 770        6    60069     4.5        122
# 2582      15     5218     2.0        186
# 5987      14      593     5.0          3
# 107       42     5418     4.0        100
# 787       38     1307     2.5        187
# 1591      30      788     2.0        199
# 5117      37     6377     4.0         54
# ...      ...      ...     ...        ...
# 5193      33     1270     3.0         33
# 1136      28    68157     4.5        175
# 3543       0      367     4.0         42
# 3706      29      110     4.5          7
# 6073       8      296     5.0          2
# 1170      31      480     4.0          6
# 2980      17     4226     4.0         41
# 5023      43     7438     4.0        105
# 3017      46       95     2.0        192
# 483       39      357     4.5        124
# 1765      36     6874     4.5         70
# 4777      27     1246     4.0        184
# 1522      12     4027     4.5        151
# 3050      46      904     3.0        190
# 2911      17      165     3.5         49
# 2321       4    68157     5.0        175
# 381       44      539     3.0        117
# 2704      26     3996     4.0        103
# 3665       0     4973     5.0         89
# 479       39      316     3.0         55
# 5709       1     1213     4.0         75
# 534       39     1917     2.5        158
# 4544      19     6874     4.0         70
# 2904      13    68954     5.0        119
# 6168       8     5218     4.5        186
# 4364      32     6539     3.0         44
# 3910       3     1961     3.0        149
# 526       39     1517     4.0        134
# 3667       0     4995     4.0         81
# 810       34        2     3.0        104
#
# [6486 rows x 4 columns]

# %%
cutoff = int(0.8*len(df))
ratings_train = df.iloc[:cutoff]
ratings_test = df.iloc[cutoff:]

# %%
K = 2
mu = ratings_train.rating.mean()
epochs=25
reg = 0
u = Input(shape = (1,))
m = Input(shape = (1,))
u_embedding = Embedding(N,K,embeddings_regularizer = l2(reg))(u)
m_embedding = Embedding(M,K,embeddings_regularizer = l2(reg))(m)

u_bias = Embedding(N,1,embeddings_regularizer = l2(reg))(u)
m_bias = Embedding(M,1,embeddings_regularizer = l2(reg))(m)
x = Dot(axes = 2)([u_embedding,m_embedding])

x = Add()([x, u_bias, m_bias])
x = Flatten()(x)

model = Model(inputs = [u, m], output = x)
# Out:
# /Users/Anant/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("fl...)`

# %%
model.compile(
loss = 'mse',
optimizer = SGD(lr = 0.007, momentum = 0.9),
#optimizer = SGD(lr = 0.009),
metrics = ['mse']
)

# %%
r = model.fit(
    x = [ratings_train.userId.values, ratings_train.movie_idx.values],
    y = ratings_train.rating.values - mu,
    epochs = epochs,
    batch_size = 64,
    validation_data = (
        [ratings_test.userId.values, ratings_test.movie_idx.values],
        ratings_test.rating.values - mu
    ),
    shuffle = False
)
# Out:
# Train on 5188 samples, validate on 1298 samples
# Epoch 1/25
# 5188/5188 [==============================] - 0s 82us/step - loss: 0.7482 - mean_squared_error: 0.7482 - val_loss: 0.7069 - val_mean_squared_error: 0.7069
# Epoch 2/25
# 5188/5188 [==============================] - 0s 48us/step - loss: 0.7020 - mean_squared_error: 0.7020 - val_loss: 0.6764 - val_mean_squared_error: 0.6764
# Epoch 3/25
# 5188/5188 [==============================] - 0s 50us/step - loss: 0.6686 - mean_squared_error: 0.6686 - val_loss: 0.6540 - val_mean_squared_error: 0.6540
# Epoch 4/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.6437 - mean_squared_error: 0.6437 - val_loss: 0.6368 - val_mean_squared_error: 0.6368
# Epoch 5/25
# 5188/5188 [==============================] - 0s 39us/step - loss: 0.6244 - mean_squared_error: 0.6244 - val_loss: 0.6230 - val_mean_squared_error: 0.6230
# Epoch 6/25
# 5188/5188 [==============================] - 0s 52us/step - loss: 0.6088 - mean_squared_error: 0.6088 - val_loss: 0.6117 - val_mean_squared_error: 0.6117
# Epoch 7/25
# 5188/5188 [==============================] - 0s 60us/step - loss: 0.5959 - mean_squared_error: 0.5959 - val_loss: 0.6021 - val_mean_squared_error: 0.6021
# Epoch 8/25
# 5188/5188 [==============================] - 0s 53us/step - loss: 0.5850 - mean_squared_error: 0.5850 - val_loss: 0.5939 - val_mean_squared_error: 0.5939
# Epoch 9/25
# 5188/5188 [==============================] - 0s 54us/step - loss: 0.5757 - mean_squared_error: 0.5757 - val_loss: 0.5868 - val_mean_squared_error: 0.5868
# Epoch 10/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.5676 - mean_squared_error: 0.5676 - val_loss: 0.5807 - val_mean_squared_error: 0.5807
# Epoch 11/25
# 5188/5188 [==============================] - 0s 50us/step - loss: 0.5606 - mean_squared_error: 0.5606 - val_loss: 0.5753 - val_mean_squared_error: 0.5753
# Epoch 12/25
# 5188/5188 [==============================] - 0s 54us/step - loss: 0.5544 - mean_squared_error: 0.5544 - val_loss: 0.5705 - val_mean_squared_error: 0.5705
# Epoch 13/25
# 5188/5188 [==============================] - 0s 66us/step - loss: 0.5489 - mean_squared_error: 0.5489 - val_loss: 0.5664 - val_mean_squared_error: 0.5664
# Epoch 14/25
# 5188/5188 [==============================] - 0s 54us/step - loss: 0.5441 - mean_squared_error: 0.5441 - val_loss: 0.5627 - val_mean_squared_error: 0.5627
# Epoch 15/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.5397 - mean_squared_error: 0.5397 - val_loss: 0.5594 - val_mean_squared_error: 0.5594
# Epoch 16/25
# 5188/5188 [==============================] - 0s 69us/step - loss: 0.5359 - mean_squared_error: 0.5359 - val_loss: 0.5565 - val_mean_squared_error: 0.5565
# Epoch 17/25
# 5188/5188 [==============================] - 0s 68us/step - loss: 0.5324 - mean_squared_error: 0.5324 - val_loss: 0.5540 - val_mean_squared_error: 0.5540
# Epoch 18/25
# 5188/5188 [==============================] - 0s 53us/step - loss: 0.5293 - mean_squared_error: 0.5293 - val_loss: 0.5518 - val_mean_squared_error: 0.5518
# Epoch 19/25
# 5188/5188 [==============================] - 0s 50us/step - loss: 0.5266 - mean_squared_error: 0.5266 - val_loss: 0.5498 - val_mean_squared_error: 0.5498
# Epoch 20/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.5241 - mean_squared_error: 0.5241 - val_loss: 0.5480 - val_mean_squared_error: 0.5480
# Epoch 21/25
# 5188/5188 [==============================] - 0s 52us/step - loss: 0.5219 - mean_squared_error: 0.5219 - val_loss: 0.5465 - val_mean_squared_error: 0.5465
# Epoch 22/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.5199 - mean_squared_error: 0.5199 - val_loss: 0.5452 - val_mean_squared_error: 0.5452
# Epoch 23/25
# 5188/5188 [==============================] - 0s 51us/step - loss: 0.5180 - mean_squared_error: 0.5180 - val_loss: 0.5440 - val_mean_squared_error: 0.5440
# Epoch 24/25
# 5188/5188 [==============================] - 0s 62us/step - loss: 0.5164 - mean_squared_error: 0.5164 - val_loss: 0.5429 - val_mean_squared_error: 0.5429
# Epoch 25/25
# 5188/5188 [==============================] - 0s 62us/step - loss: 0.5149 - mean_squared_error: 0.5149 - val_loss: 0.5420 - val_mean_squared_error: 0.5420

# %%
plt.plot(r.history['loss'],label = "train_loss")
plt.plot(r.history['val_loss'],label = "test_loss")
plt.legend()
plt.show()

# %%
model.save('martrix_factorization.h5')

# %%
from keras.models import load_model

# %%
new_model = load_model('martrix_factorization.h5')

# %%
#new_model.summary()
# new_model.get_weights()
